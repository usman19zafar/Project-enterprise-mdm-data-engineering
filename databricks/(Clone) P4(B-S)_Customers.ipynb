# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window

# %%
bronze_path_customers = "<location>"

df_bronze_customers = spark.read.format("delta").load(bronze_path_customers)

# %%
source_system = "customers"
business_key = "customer_id"
load_timestamp = F.current_timestamp()

# %%
schema_contract = {
    "customer_id": "int",
    "first_name": "string",
    "last_name": "string",
    "email": "string",
    "phone": "string",
    "city": "string",
    "state": "string",
    "signup_date": "date"
}

# %%
mapping_rules = {
    "first_name":   lambda c: F.initcap(F.trim(F.col(c))),
    "last_name":    lambda c: F.initcap(F.trim(F.col(c))),
    "email":        lambda c: F.lower(F.trim(F.col(c))),
    "phone":        lambda c: F.trim(F.col(c)),
    "city":         lambda c: F.initcap(F.trim(F.col(c))),
    "state":        lambda c: F.upper(F.trim(F.col(c))),
    "signup_date": lambda c: F.coalesce(
        F.try_to_date(F.col(c), "yyyy-MM-dd"),
        F.try_to_date(F.col(c), "MM/dd/yyyy"),
        F.try_to_date(F.col(c), "M/d/yyyy"),
        F.try_to_date(F.col(c), "dd/MM/yyyy"),
        F.try_to_date(F.col(c), "d/M/yyyy")
    )

}

# %%
df_transformed = df_bronze_customers

for col_name, rule in mapping_rules.items():
    df_transformed = df_transformed.withColumn(col_name, rule(col_name))

# %%
for col_name, data_type in schema_contract.items():
    df_transformed = df_transformed.withColumn(col_name, F.col(col_name).cast(data_type))

# %%
window_spec = Window.partitionBy(business_key).orderBy(F.col("raw_ingestion_timestamp").desc())

df_deduped = (
    df_transformed
    .withColumn("rn", F.row_number().over(window_spec))
    .filter("rn = 1")
    .drop("rn")
)

# %%
df_silver_customers = (
    df_deduped
    .withColumn("silver_load_timestamp", load_timestamp)
    .withColumn("silver_source_system", F.lit(source_system))
)

# %%
silver_path_customers = "<location>"

df_silver_customers.write.format("delta").mode("overwrite").save(silver_path_customers)

# %%
spark.read.format("delta").load(silver_path_customers).show()
# Out:
# +-----------+----------+---------+--------------------+--------------------+---------------+-----+-----------+--------------------+-----------------------+---------------------+--------------------+
# |customer_id|first_name|last_name|               email|               phone|           city|state|signup_date|       raw_file_path|raw_ingestion_timestamp|silver_load_timestamp|silver_source_system|
# +-----------+----------+---------+--------------------+--------------------+---------------+-----+-----------+--------------------+-----------------------+---------------------+--------------------+
# |          1|    Andrew|    Smith|                NULL|          5486653565|   Nicholasland|   MP| 2024-10-04|abfss://chatgptpr...|   2026-02-04 23:47:...| 2026-02-05 00:04:...|           customers|
# |          2|      Ruth|    Walsh|  mary50@example.net|001-898-507-5175x609|   Port Antonio|   IA| 2023-03-14|abfss://chatgptpr...|   2026-02-04 23:47:...| 2026-02-05 00:04:...|           customers|
# |          3|   Sabrina|     Bell|                NULL|                NULL|     Jacobhaven|   PW| 2024-09-28|abfss://chatgptpr...|   2026-02-04 23:47:...| 2026-02-05 00:04:...|           customers|
# |          4|    Andrea|  Goodman| james26@example.org|001-299-652-7491x...|       New Cody|   KS| 2023-12-15|abfss://chatgptpr...|   2026-02-04 23:47:...| 2026-02-05 00:04:...|           customers|
# |          5|   Michael|     Ware|garyreed@example.org|        603.323.8518|North Laurafort|   MA| 2023-11-26|abfss://chatgptpr...|   2026-02-04 23:47:...| 2026-02-05 00:04:...|           customers|
# |          6|   William|  Johnson| hmorgan@example.org|   524.442.0451x8773|     Shelialand|   AK| 2025-05-17|abfss://chatgptpr...|   2026-02-04 23:47:...| 2026-02-05 00:04:...|           customers|
# |          7|  Kathleen|     Wang|susanatkins@examp...|   341-996-6536x2141|   Lake Johnton|   GU| 2025-11-18|abfss://chatgptpr...|   2026-02-04 23:47:...| 2026-02-05 00:04:...|           customers|
# |          8|     Larry|  Burgess|                NULL|+1-514-964-5268x3...|    East Angela|   DE| 2025-10-31|abfss://chatgptpr...|   2026-02-04 23:47:...| 2026-02-05 00:04:...|           customers|
# |          9|     Scott|     Dean|                NULL|          4205109865|      Brownland|   PA| 2023-04-03|abfss://chatgptpr...|   2026-02-04 23:47:...| 2026-02-05 00:04:...|           customers|
# |         10|    Mathew|    Weber| heidi15@example.net|                NULL|      Burkebury|   RI| 2023-09-15|abfss://chatgptpr...|   2026-02-04 23:47:...| 2026-02-05 00:04:...|           customers|
# |         11|      Kurt|  Mcclain| dfields@example.com|+1-215-236-2572x8...| Port Catherine|   AS| 2023-05-15|abfss://chatgptpr...|   2026-02-04 23:47:...| 2026-02-05 00:04:...|           customers|
# |         12|      Lisa|     Yang|                NULL|  288.344.5426x65607|        Amyland|   AL| 2023-11-11|abfss://chatgptpr...|   2026-02-04 23:47:...| 2026-02-05 00:04:...|           customers|
# |         13|    Leslie|   Pierce|jennifer30@exampl...|                NULL|      Costaland|   DE| 2023-06-06|abfss://chatgptpr...|   2026-02-04 23:47:...| 2026-02-05 00:04:...|           customers|
# |         14|      John|     Shaw|                NULL|    658-905-0143x302|      Henrybury|   RI| 2023-09-02|abfss://chatgptpr...|   2026-02-04 23:47:...| 2026-02-05 00:04:...|           customers|
# |         15|    Joseph|  Randall|shellyarmstrong@e...|   560-657-0451x7072|   Jacksonmouth|   MA| 2025-06-11|abfss://chatgptpr...|   2026-02-04 23:47:...| 2026-02-05 00:04:...|           customers|
# |         16|     Karen|  Johnson| james75@example.net| (299)294-2218x67000|       Cainfurt|   MI| 2023-11-07|abfss://chatgptpr...|   2026-02-04 23:47:...| 2026-02-05 00:04:...|           customers|
# |         17|   Rebecca|    Rivas|                NULL|          4446033438|   Danielsshire|   WY| 2025-06-26|abfss://chatgptpr...|   2026-02-04 23:47:...| 2026-02-05 00:04:...|           customers|
# |         18|   Lindsey|    Jones|rivaschristopher@...|+1-285-714-6066x0496| East Angelland|   NM| 2023-09-22|abfss://chatgptpr...|   2026-02-04 23:47:...| 2026-02-05 00:04:...|           customers|
# |         19|   Michael|  Shepard|                NULL|  475-375-5595x90668|     Leslieberg|   MS| 2024-04-09|abfss://chatgptpr...|   2026-02-04 23:47:...| 2026-02-05 00:04:...|           customers|
# |         20|    Travis|   Wilcox|solisroberto@exam...|        228.431.0771|     Lake James|   PR| 2025-09-01|abfss://chatgptpr...|   2026-02-04 23:47:...| 2026-02-05 00:04:...|           customers|
# +-----------+----------+---------+--------------------+--------------------+---------------+-----+-----------+--------------------+-----------------------+---------------------+--------------------+
# only showing top 20 rows
